# %% [markdown]
# ## Loading basic Python and R imports

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %% [markdown]
# # Answer the questions below. Explain your reasoning.

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0     ✔ purrr   0.3.5
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Part 1 | mtcars
#
# ### 👉 Question 1: Are automatic cars more fuel efficent than manual cars?

# %%
# %%R -o mtcars
#
# ggplot(mtcars) +
#     aes(x=factor(am), y=mpg, color=factor(am)) +
#     geom_point(size=4, alpha=.4) +
#     theme_minimal()

# %%
# python cell
mtcars
# Out:
#                       mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# Mazda RX4            21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# Mazda RX4 Wag        21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# Datsun 710           22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0
# Hornet 4 Drive       21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0
# Hornet Sportabout    18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
# Valiant              18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0  0.0
# Duster 360           14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0  0.0
# Merc 240D            24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0  0.0
# Merc 230             22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0  0.0
# Merc 280             19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0  0.0
# Merc 280C            17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0  0.0
# Merc 450SE           16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0  0.0
# Merc 450SL           17.3  8.0  275.8  180.0  3.07  3.730  17.60  0.0  0.0
# Merc 450SLC          15.2  8.0  275.8  180.0  3.07  3.780  18.00  0.0  0.0
# Cadillac Fleetwood   10.4  8.0  472.0  205.0  2.93  5.250  17.98  0.0  0.0
# Lincoln Continental  10.4  8.0  460.0  215.0  3.00  5.424  17.82  0.0  0.0
# Chrysler Imperial    14.7  8.0  440.0  230.0  3.23  5.345  17.42  0.0  0.0
# Fiat 128             32.4  4.0   78.7   66.0  4.08  2.200  19.47  1.0  1.0
# Honda Civic          30.4  4.0   75.7   52.0  4.93  1.615  18.52  1.0  1.0
# Toyota Corolla       33.9  4.0   71.1   65.0  4.22  1.835  19.90  1.0  1.0
# Toyota Corona        21.5  4.0  120.1   97.0  3.70  2.465  20.01  1.0  0.0
# Dodge Challenger     15.5  8.0  318.0  150.0  2.76  3.520  16.87  0.0  0.0
# AMC Javelin          15.2  8.0  304.0  150.0  3.15  3.435  17.30  0.0  0.0
# Camaro Z28           13.3  8.0  350.0  245.0  3.73  3.840  15.41  0.0  0.0
# Pontiac Firebird     19.2  8.0  400.0  175.0  3.08  3.845  17.05  0.0  0.0
# Fiat X1-9            27.3  4.0   79.0   66.0  4.08  1.935  18.90  1.0  1.0
# Porsche 914-2        26.0  4.0  120.3   91.0  4.43  2.140  16.70  0.0  1.0
# Lotus Europa         30.4  4.0   95.1  113.0  3.77  1.513  16.90  1.0  1.0
# Ford Pantera L       15.8  8.0  351.0  264.0  4.22  3.170  14.50  0.0  1.0
# Ferrari Dino         19.7  6.0  145.0  175.0  3.62  2.770  15.50  0.0  1.0
# Maserati Bora        15.0  8.0  301.0  335.0  3.54  3.570  14.60  0.0  1.0
# Volvo 142E           21.4  4.0  121.0  109.0  4.11  2.780  18.60  1.0  1.0
#
#                      gear  carb
# Mazda RX4             4.0   4.0
# Mazda RX4 Wag         4.0   4.0
# Datsun 710            4.0   1.0
# Hornet 4 Drive        3.0   1.0
# Hornet Sportabout     3.0   2.0
# Valiant               3.0   1.0
# Duster 360            3.0   4.0
# Merc 240D             4.0   2.0
# Merc 230              4.0   2.0
# Merc 280              4.0   4.0
# Merc 280C             4.0   4.0
# Merc 450SE            3.0   3.0
# Merc 450SL            3.0   3.0
# Merc 450SLC           3.0   3.0
# Cadillac Fleetwood    3.0   4.0
# Lincoln Continental   3.0   4.0
# Chrysler Imperial     3.0   4.0
# Fiat 128              4.0   1.0
# Honda Civic           4.0   2.0
# Toyota Corolla        4.0   1.0
# Toyota Corona         3.0   1.0
# Dodge Challenger      3.0   2.0
# AMC Javelin           3.0   2.0
# Camaro Z28            3.0   4.0
# Pontiac Firebird      3.0   2.0
# Fiat X1-9             4.0   1.0
# Porsche 914-2         5.0   2.0
# Lotus Europa          5.0   2.0
# Ford Pantera L        5.0   4.0
# Ferrari Dino          5.0   6.0
# Maserati Bora         5.0   8.0
# Volvo 142E            4.0   2.0

# %% [markdown]
# ## Part 2 | Last Year's Polly (Anonymized)

# %% [markdown]
# ### 👉 Question 2: Are Dhrumil's students more stressed than Irena's?

# %%
# %%R
#
# # read some functions from the functions.R file
# source('functions.R')

# %%
# %%R -o q_emotions
#
# q_emotions <- read_csv('emotion.csv', show_col_types = FALSE) %>%
#         mutate(date=as.Date(date),
#         emoji = factor(emoji, levels=c('😍', '🙂', '😐', '🙁', '😢')))
#
# q_emotions
# Out:
# # A tibble: 585 × 6
#    date       user_id                          choice_id emoji question editor
#    <date>     <chr>                                <dbl> <fct> <chr>    <chr>
#  1 2022-05-13 aa516cd83ca47c4c0707d31047f6dc8a         2 😍    emotion  Dhrumil
#  2 2022-05-13 5a7ac9a0ee30d1e7bedafd9046162fc7         1 🙂    emotion  Dhrumil
#  3 2022-05-13 fb6da81da7c9b66f4dfd266096bca702         2 😍    emotion  Dhrumil
#  4 2022-05-13 f2dfc7b67a37987df95bd920a81a5cd3         1 🙂    emotion  Irena
#  5 2022-05-13 764f85855c5a57c62401a0834eda0fc9         1 🙂    emotion  Dhrumil
#  6 2022-05-13 95ba860ed905cf268092ca1e90f91dd6         2 😍    emotion  Irena
#  7 2022-05-13 3ce992bb73ea135b1c738ef290cb93d5         2 😍    emotion  Dhrumil
#  8 2022-05-13 c21a2438c0e9308e03a92ebd90c5d27d         0 😐    emotion  Dhrumil
#  9 2022-05-13 89135d5c75496c9d94251f30c748b9b8        -2 😢    emotion  Irena
# 10 2022-05-13 5119dd707d353a28b41fa1adcdda76be         2 😍    emotion  Dhrumil
# # … with 575 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1200
#
# plot_type_1(q_emotions)

# %%
q_emotions = pd.read_csv('emotion.csv', parse_dates=['date'])
q_emotions
# Out:
#           date                           user_id  choice_id emoji question  \
# 0   2022-05-13  aa516cd83ca47c4c0707d31047f6dc8a          2     😍  emotion
# 1   2022-05-13  5a7ac9a0ee30d1e7bedafd9046162fc7          1     🙂  emotion
# 2   2022-05-13  fb6da81da7c9b66f4dfd266096bca702          2     😍  emotion
# 3   2022-05-13  f2dfc7b67a37987df95bd920a81a5cd3          1     🙂  emotion
# 4   2022-05-13  764f85855c5a57c62401a0834eda0fc9          1     🙂  emotion
# ..         ...                               ...        ...   ...      ...
# 580 2022-01-21  aa516cd83ca47c4c0707d31047f6dc8a          2     😍  emotion
# 581 2022-01-21  4716f7a2eee28bddd0e115f021642950          2     😍  emotion
# 582 2022-01-21  8b728352298677976121c9bcf5f2a578          1     🙂  emotion
# 583 2022-01-21  5a7ac9a0ee30d1e7bedafd9046162fc7          1     🙂  emotion
# 584 2022-01-21  fb6da81da7c9b66f4dfd266096bca702          2     😍  emotion
#
#       editor
# 0    Dhrumil
# 1    Dhrumil
# 2    Dhrumil
# 3      Irena
# 4    Dhrumil
# ..       ...
# 580  Dhrumil
# 581  Dhrumil
# 582    Irena
# 583  Dhrumil
# 584  Dhrumil
#
# [585 rows x 6 columns]

# %%
# hint: try a pivot table (or a group by)

# %%
# %%R
#
# q_emotions_d = q_emotions %>% filter(editor=='Dhrumil')
# q_emotions_i = q_emotions %>% filter(editor=='Irena')
#
# t.test(q_emotions_d$choice_id, q_emotions_i$choice_id)
# Out:
# 	Welch Two Sample t-test
#
# data:  q_emotions_d$choice_id and q_emotions_i$choice_id
# t = 1.7076, df = 582.95, p-value = 0.08825
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.01825952  0.26141742
# sample estimates:
# mean of x mean of y
# 0.7566667 0.6350877

# %% [markdown]
# ### 👉 Question 3: Do Dhrumil's students have a heavier workload than Irena's?

# %%
# %%R
#
# q_workload <- read_csv('workload.csv', show_col_types = FALSE)
# q_workload
# Out:
# # A tibble: 543 × 5
#    date       user_id                          choice_id question editor
#    <date>     <chr>                                <dbl> <chr>    <chr>
#  1 2022-05-13 aa516cd83ca47c4c0707d31047f6dc8a         2 workload Dhrumil
#  2 2022-05-13 5a7ac9a0ee30d1e7bedafd9046162fc7         4 workload Irena
#  3 2022-05-13 fb6da81da7c9b66f4dfd266096bca702         6 workload Dhrumil
#  4 2022-05-13 f2dfc7b67a37987df95bd920a81a5cd3         3 workload Dhrumil
#  5 2022-05-13 764f85855c5a57c62401a0834eda0fc9         4 workload Dhrumil
#  6 2022-05-13 95ba860ed905cf268092ca1e90f91dd6         2 workload Irena
#  7 2022-05-13 3ce992bb73ea135b1c738ef290cb93d5         5 workload Irena
#  8 2022-05-13 c21a2438c0e9308e03a92ebd90c5d27d         4 workload Irena
#  9 2022-05-13 a9864a7d130ce52cf17579545fc96643         5 workload Dhrumil
# 10 2022-05-13 5119dd707d353a28b41fa1adcdda76be         1 workload Dhrumil
# # … with 533 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1200
#
# # Data at a glance
# plot_type_2(q_workload)

# %%
q_workload = pd.read_csv('workload.csv', parse_dates=['date'])
q_workload
# Out:
#           date                           user_id  choice_id  question   editor
# 0   2022-05-13  aa516cd83ca47c4c0707d31047f6dc8a          2  workload  Dhrumil
# 1   2022-05-13  5a7ac9a0ee30d1e7bedafd9046162fc7          4  workload    Irena
# 2   2022-05-13  fb6da81da7c9b66f4dfd266096bca702          6  workload  Dhrumil
# 3   2022-05-13  f2dfc7b67a37987df95bd920a81a5cd3          3  workload  Dhrumil
# 4   2022-05-13  764f85855c5a57c62401a0834eda0fc9          4  workload  Dhrumil
# ..         ...                               ...        ...       ...      ...
# 538 2022-01-28  5119dd707d353a28b41fa1adcdda76be          6  workload  Dhrumil
# 539 2022-01-28  b049b7eae43713e6aca6320c57b3bb88          8  workload    Irena
# 540 2022-01-28  5a7ac9a0ee30d1e7bedafd9046162fc7          6  workload    Irena
# 541 2022-01-28  2ab5e1542adfb5cbd739a0e443d7408b          5  workload    Irena
# 542 2022-01-28  a9864a7d130ce52cf17579545fc96643          5  workload  Dhrumil
#
# [543 rows x 5 columns]

# %%
# hint: try a pivot table (or a group by)

# %%
q_workload = pd.read_csv('workload.csv')
q_workload
# Out:
#            date                           user_id  choice_id  question  \
# 0    2022-05-13  aa516cd83ca47c4c0707d31047f6dc8a          2  workload
# 1    2022-05-13  5a7ac9a0ee30d1e7bedafd9046162fc7          4  workload
# 2    2022-05-13  fb6da81da7c9b66f4dfd266096bca702          6  workload
# 3    2022-05-13  f2dfc7b67a37987df95bd920a81a5cd3          3  workload
# 4    2022-05-13  764f85855c5a57c62401a0834eda0fc9          4  workload
# ..          ...                               ...        ...       ...
# 538  2022-01-28  5119dd707d353a28b41fa1adcdda76be          6  workload
# 539  2022-01-28  b049b7eae43713e6aca6320c57b3bb88          8  workload
# 540  2022-01-28  5a7ac9a0ee30d1e7bedafd9046162fc7          6  workload
# 541  2022-01-28  2ab5e1542adfb5cbd739a0e443d7408b          5  workload
# 542  2022-01-28  a9864a7d130ce52cf17579545fc96643          5  workload
#
#       editor
# 0    Dhrumil
# 1      Irena
# 2    Dhrumil
# 3    Dhrumil
# 4    Dhrumil
# ..       ...
# 538  Dhrumil
# 539    Irena
# 540    Irena
# 541    Irena
# 542  Dhrumil
#
# [543 rows x 5 columns]

# %%
df = q_workload.groupby('editor').choice_id.mean()
df
# Out:
# editor
# Dhrumil    6.658120
# Irena      6.886731
# Name: choice_id, dtype: float64

# %%
# %%R
#
# q_workload_d = q_workload %>% filter(editor=='Dhrumil')
# q_workload_i = q_workload %>% filter(editor=='Irena')
#
# t.test(q_workload_d$choice_id, q_workload_i$choice_id)
# Out:
# 	Welch Two Sample t-test
#
# data:  q_workload_d$choice_id and q_workload_i$choice_id
# t = -1.4969, df = 498.05, p-value = 0.1351
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.52867962  0.07145615
# sample estimates:
# mean of x mean of y
#  6.658120  6.886731

# %% [markdown]
# The difference of mean is 0.23, but the p value shows that there is likely to be that Irena's student have higher stress level.

# %% [markdown]
# # Pollster Ratings
#
# ### 👉 Question 4: Are Gubernatorial Polls More Accurate Than Senate Polls?

# %%
# %%R
#
# s_g_polls <- read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/pollster-ratings/raw-polls.csv', show_col_types = FALSE) %>%
#     filter(type_detail %in% c('Gov-G', 'Sen-G')) %>%
#     filter(location != 'US')
#
#
# s_g_polls
# Out:
# # A tibble: 4,014 × 33
#    poll_id questio…¹ race_id  year race  locat…² type_…³ type_…⁴ polls…⁵ polls…⁶
#      <dbl>     <dbl>   <dbl> <dbl> <chr> <chr>   <chr>   <chr>   <chr>     <dbl>
#  1   26013     87909    1455  1998 1998… NY      Gov-G   Gov-G   Blum &…      32
#  2   26255     87926    1456  1998 1998… OH      Gov-G   Gov-G   Univer…     346
#  3   26026     31266    1736  1998 1998… NV      Sen-G   Sen-G   FM3 Re…      91
#  4   26013     31253    1738  1998 1998… NY      Sen-G   Sen-G   Blum &…      32
#  5   63632    117103    1738  1998 1998… NY      Sen-G   Sen-G   Garin-…     113
#  6   26255     31495    1741  1998 1998… OH      Sen-G   Sen-G   Univer…     346
#  7   54202     87738    1435  1998 1998… AZ      Gov-G   Gov-G   Behavi…      27
#  8   54291     87827    1443  1998 1998… IL      Gov-G   Gov-G   WCIA-TV     373
#  9   54273     87809    1444  1998 1998… IA      Gov-G   Gov-G   Drake …     329
# 10   54346     87882    1451  1998 1998… NE      Gov-G   Gov-G   Mason-…     197
# # … with 4,004 more rows, 23 more variables: methodology <chr>, partisan <chr>,
# #   polldate <chr>, samplesize <dbl>, cand1_name <chr>, cand1_id <dbl>,
# #   cand1_party <chr>, cand1_pct <dbl>, cand2_name <chr>, cand2_id <dbl>,
# #   cand2_party <chr>, cand2_pct <dbl>, cand3_pct <dbl>, margin_poll <dbl>,
# #   electiondate <chr>, cand1_actual <dbl>, cand2_actual <dbl>,
# #   margin_actual <dbl>, error <dbl>, bias <dbl>, rightcall <dbl>,
# #   advancedplusminus <dbl>, comment <chr>, and abbreviated variable names …
# # ℹ Use `print(n = ...)` to see more rows, and `colnames()` to see all variable names

# %%
# %%R -w 1000
#
# mean_bias <- s_g_polls %>%
# filter(!is.na(bias)) %>%
#     group_by(type_detail) %>%
#     summarise(bias=mean(bias))
#
# ggplot(s_g_polls) +
#     aes(x=bias, fill=type_detail) +
#     geom_histogram(alpha=.5, bins=100, position='identity') +
#     geom_vline(data=mean_bias, aes(xintercept=bias, color=type_detail))

# %%
s_g_polls = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/pollster-ratings/raw-polls.csv') \
    .query("type_detail.isin(['Gov-G', 'Sen-G'])")\
    .query("location!='US'")           

s_g_polls
# Out:
#        poll_id  question_id  race_id  year           race location  \
# 0        26013        87909     1455  1998  1998_Gov-G_NY       NY
# 1        26255        87926     1456  1998  1998_Gov-G_OH       OH
# 2        26026        31266     1736  1998  1998_Sen-G_NV       NV
# 3        26013        31253     1738  1998  1998_Sen-G_NY       NY
# 4        63632       117103     1738  1998  1998_Sen-G_NY       NY
# ...        ...          ...      ...   ...            ...      ...
# 10725    72624       136296     6280  2020  2020_Sen-G_MI       MI
# 10726    72625       136297     6281  2020  2020_Sen-G_MN       MN
# 10727    72626       136298     6287  2020  2020_Sen-G_NJ       NJ
# 10728    72864       140394     6292  2020  2020_Sen-G_SC       SC
# 10741    72621       136284     6272  2020  2020_Sen-G_IA       IA
#
#       type_simple type_detail                              pollster  \
# 0           Gov-G       Gov-G              Blum & Weprin Associates
# 1           Gov-G       Gov-G  University of Cincinnati (Ohio Poll)
# 2           Sen-G       Sen-G                          FM3 Research
# 3           Sen-G       Sen-G              Blum & Weprin Associates
# 4           Sen-G       Sen-G        Garin-Hart-Yang Research Group
# ...           ...         ...                                   ...
# 10725       Sen-G       Sen-G                          Research Co.
# 10726       Sen-G       Sen-G                          Research Co.
# 10727       Sen-G       Sen-G                          Research Co.
# 10728       Sen-G       Sen-G                               Optimus
# 10741       Sen-G       Sen-G                 Public Policy Polling
#
#        pollster_rating_id  ... margin_poll electiondate cand1_actual  \
# 0                      32  ...       -31.0    11/3/1998        33.16
# 1                     346  ...       -15.0    11/3/1998        44.69
# 2                      91  ...         5.0    11/3/1998        47.86
# 3                      32  ...        -8.0    11/3/1998        54.62
# 4                     113  ...         4.0    11/3/1998        54.62
# ...                   ...  ...         ...          ...          ...
# 10725                 449  ...        15.0    11/3/2020        49.90
# 10726                 449  ...        11.0    11/3/2020        48.74
# 10727                 449  ...        23.0    11/3/2020        57.23
# 10728                 245  ...        -9.8    11/3/2020        44.17
# 10741                 263  ...         1.0    11/3/2020        45.15
#
#        cand2_actual margin_actual  error   bias  rightcall advancedplusminus  \
# 0             54.32        -21.15   9.85  -9.85        1.0          1.461561
# 1             50.05         -5.36   9.64  -9.64        1.0          4.285789
# 2             47.77          0.09   4.91   4.91        1.0         -1.023784
# 3             44.08         10.54  18.54 -18.54        0.0         10.064104
# 4             44.08         10.54   6.54  -6.54        1.0         -1.972391
# ...             ...           ...    ...    ...        ...               ...
# 10725         48.22          1.69  13.31  13.31        1.0          8.305356
# 10726         43.50          5.24   5.76   5.76        1.0          1.249939
# 10727         40.92         16.31   6.69   6.69        1.0          0.357477
# 10728         54.44        -10.27   0.47   0.47        1.0         -6.938997
# 10741         51.74         -6.59   7.59   7.59        0.0          1.184997
#
#                                             comment
# 0      for New York Daily News | WABC-TV (New York)
# 1                                               NaN
# 2                for unspecified Democratic sponsor
# 3      for New York Daily News | WABC-TV (New York)
# 4                            for Charles E. Schumer
# ...                                             ...
# 10725                                           NaN
# 10726                                           NaN
# 10727                                           NaN
# 10728                                           NaN
# 10741                                among 'voters'
#
# [4014 rows x 33 columns]

# %%
# %%R
#
# s_g_polls_s = s_g_polls %>% filter(type_simple=='Sen-G')
# s_g_polls_g = s_g_polls %>% filter(type_simple=='Gov-G')
#
# t.test(s_g_polls_s$bias, s_g_polls_g$bias)
# Out:
# 	Welch Two Sample t-test
#
# data:  s_g_polls_s$bias and s_g_polls_g$bias
# t = -1.5609, df = 3408.6, p-value = 0.1186
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.74691303  0.08478878
# sample estimates:
# mean of x mean of y
# 0.1366380 0.4677001

# %% [markdown]
# The p value is higher than 0.05, so there is a significant difference between the accuracy of the two polls. Sen G tends to be more accurate.
